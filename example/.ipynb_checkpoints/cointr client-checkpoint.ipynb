# %%
import sys

sys.path.append(r'E:\HftStrategy\NodeltaHftSystem')

# %%
import nodelta
# Out:
# 已添加第三方SDK环境变量: E:\HftStrategy\NodeltaHftSystem\nodelta\gateway\SDK\binance_sdk

# %%
from nodelta.gateway.SDK.cointr_sdk.um_futures.websocket_client import UMFuturesWebsocketClient

# %%
WEBSOCKET_HOST: str = r"wss://stream.cointr.pro/ws"

def on_message(data):
    print(data)
    
ws_client = UMFuturesWebsocketClient(WEBSOCKET_HOST, on_message=on_message)

# %%
ws_client.start()
# Out:
# {"code":0,"msg":"connect.success","ts":1690118861482,"id":"f6d0ddfffe5e0739-00000001-0053aa2b-e2387f6677adc4a9-3feec70e"}
# {'code': 0, 'msg': 'connect.success', 'ts': 1690118861482, 'id': 'f6d0ddfffe5e0739-00000001-0053aa2b-e2387f6677adc4a9-3feec70e'}
# WebsocketClient on error----------
# [2023-07-23T21:29:45.522046]: Unhandled WebSocket Error:<class 'aiohttp.client_exceptions.WSServerHandshakeError'>
# LastSentText:
#
# LastReceivedText:
# {"code":0,"msg":"connect.success","ts":1690118861482,"id":"f6d0ddfffe5e0739-00000001-0053aa2b-e2387f6677adc4a9-3feec70e"}
# Exception trace:
# Traceback (most recent call last):
#   File "E:\HftStrategy\NodeltaHftSystem\nodelta\gateway\SDK\cointr_sdk\um_futures\websocket_client.py", line 38, in _run
#   File "C:\Anaconda\lib\site-packages\aiohttp\client.py", line 774, in _ws_connect
#     headers=resp.headers,
# aiohttp.client_exceptions.WSServerHandshakeError: 403, message='Invalid response status', url=URL('wss://stream.cointr.pro/ws')
#
# ...
